# %% [markdown]
# # **Escuela Politécnica Nacional**
# ## **Nombre:** Liam Zúñiga
# ## **Fecha:** 2024-12-03

# %% [markdown]
# # **[Actividad extracurricular 07] python formatters**

# %% [markdown]
# ### Black Formatter

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### yapf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### autopep8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### isort

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Link de GitHub

# %% [markdown]
# https://github.com/Riamu360/FormattersPython_LiamZ
